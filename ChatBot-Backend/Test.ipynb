# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv

load_dotenv()

client = AzureOpenAI(
    api_key=os.getenv('AZURE_OPENAI_API_KEY'),
    api_version=os.getenv('AZURE_OPENAI_API_VERSION'),
    azure_endpoint=os.getenv('AZURE_OPENAI_ENDPOINT'),
)
DEPLOYMENT = os.getenv('AZURE_OPENAI_CHAT_DEPLOYMENT')

user_message = 'Hello, who are you?'

response = client.chat.completions.create(
    model=DEPLOYMENT,
    messages=[
        {'role': 'system', 'content': 'You are a helpful assistant.'},
        {'role': 'user', 'content': user_message}
    ],
    max_completion_tokens=800,
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm your helpful AI assistant, here to assist you with any questions, tasks, or information you need. How can I help you today? 😊

# %%
import os
from dotenv import load_dotenv

load_dotenv(r"c:\Users\jainnayan\My-Projs\Bot_project\ChatBot-Backend\.env")

print("ENDPOINT:", os.getenv("AZURE_OPENAI_ENDPOINT"))
print("DEPLOYMENT:", os.getenv("AZURE_OPENAI_DEPLOYMENT"))
print("API_VERSION:", os.getenv("AZURE_OPENAI_API_VERSION"))
print("KEY set:", bool(os.getenv("AZURE_OPENAI_API_KEY")))
# Out:
# ENDPOINT: https://nayan-projects-openai.openai.azure.com/
# DEPLOYMENT: None
# API_VERSION: 2023-05-15
# KEY set: True
