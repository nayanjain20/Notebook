# %%
# !pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/734.6 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/734.6 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 734.6/734.6 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import openai
from openai import AzureOpenAI

client = AzureOpenAI(
    api_key="8iv07mjGSv3ZNOSXU2ICUvqU5OzmsBiCwZGSKc4eDchMEaN0DJ76JQQJ99BFAC77bzfXJ3w3AAABACOGjHlW",
    api_version="2024-02-15-preview",
    azure_endpoint="https://gem-bot.openai.azure.com/"
)


# openai.api_type = "azure"
# openai.api_base = "https://gem-bot.openai.azure.com/"
# openai.api_version = "2024-02-15-preview"
# openai.api_key =   # Ideally store this in a secure way

# %%
response = client.chat.completions.create(
    model="gpt-4",  # Not the model name! Use the deployment name
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain quantum computing in simple terms."}
    ],
    temperature=0.7,
    max_tokens=200
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="gpt-4",  # Not the model name! Use the deployment name
#       3     messages=[
#       4         {"role": "system", "content": "You are a helpful assistant."},
#       5         {"role": "user", "content": "Explain quantum computing in simple terms."}
#       6     ],
#       7     temperature=0.7,
#       8     max_tokens=200
#       9 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# ...

# %%
API_KEY = "8iv07mjGSv3ZNOSXU2ICUvqU5OzmsBiCwZGSKc4eDchMEaN0DJ76JQQJ99BFAC77bzfXJ3w3AAABACOGjHlW"

# %%
import openai

openai.api_key = API_KEY
openai.api_base = "https://gem-bot.openai.azure.com/"
openai.api_type = "azure"
openai.api_version = "2024-02-15-preview"  # Or match what you selected in Azure

# %%
response = openai.ChatCompletion.create(
    engine="your-deployment-name",  # ✅ Use deployment name from Azure
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, who are you?"},
    ],
    temperature=0.7,
    max_tokens=200
)
print(response["choices"][0]["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 response = openai.ChatCompletion.create(
#       2     engine="your-deployment-name",  # ✅ Use deployment name from Azure
#       3     messages=[
#       4         {"role": "system", "content": "You are a helpful assistant."},
#       5         {"role": "user", "content": "Hello, who are you?"},
#       6     ],
#       7     temperature=0.7,
#       8     max_tokens=200
#       9 )
#      10 print(response["choices"][0]["message"]["content"])
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# ...

# %%
from openai import AzureOpenAI

client = AzureOpenAI(
    api_key=API_KEY,  # Or just paste the key as a string
    api_version="2024-02-15-preview",
    azure_endpoint="https://gem-bot.openai.azure.com/",  # Your Azure endpoint
)

response = client.chat.completions.create(
    model="gem-bot",  # ⚠️ Use deployment name, NOT model name like "gpt-4"
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, who are you?"},
    ],
    temperature=0.7,
    max_tokens=200,
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 9
#       1 from openai import AzureOpenAI
#       3 client = AzureOpenAI(
#       4     api_key=API_KEY,  # Or just paste the key as a string
#       5     api_version="2024-02-15-preview",
#       6     azure_endpoint="https://gem-bot.openai.azure.com/",  # Your Azure endpoint
#       7 )
# ----> 9 response = client.chat.completions.create(
#      10     model="gem-bot",  # ⚠️ Use deployment name, NOT model name like "gpt-4"
#      11     messages=[
#      12         {"role": "system", "content": "You are a helpful assistant."},
#      13         {"role": "user", "content": "Hello, who are you?"},
#      14     ],
#      15     temperature=0.7,
#      16     max_tokens=200,
#      17 )
#      19 print(response.choices[0].message.content)
#
# ...

# %%
import os
from openai import AzureOpenAI



endpoint = "https://nayan-mc7nr0ma-eastus2.cognitiveservices.azure.com/"
model_name = "gpt-4.1"
deployment = "gpt-4.1"

API_KEY = "3y5s52ZV6gnd0Az92y0IUnrz7reqcyNTntyoowOcMWL0lF5MgC7AJQQJ99BFACHYHv6XJ3w3AAAAACOG1yJP"


subscription_key = API_KEY
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_completion_tokens=800,
    temperature=1.0,
    top_p=1.0,
    frequency_penalty=0.0,
    presence_penalty=0.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# That’s wonderful—Paris is a fantastic city with so much to see and do! Here are some of the must-see sights and experiences:
#
# ### Classic Sights
# - **Eiffel Tower**: Go up for stunning views or picnic on the Champs de Mars.
# - **Louvre Museum**: Home to the Mona Lisa, Venus de Milo, and countless masterpieces. Tip: Visit early or book tickets in advance.
# - **Notre-Dame Cathedral**: Even after the fire, its exterior and the nearby Seine riverbanks are beautiful.
# - **Musée d’Orsay**: Fantastic collection of Impressionist art housed in a beautiful old railway station.
# - **Arc de Triomphe**: Climb to the top for panoramic views of Paris.
#
# ### Charming Neighborhoods
# - **Montmartre**: Historic, bohemian atmosphere; see the Sacré-Cœur, cafés, and artists’ square (Place du Tertre).
# - **Le Marais**: Trendy district with cobbled streets, boutiques, cafés, and the gorgeous Place des Vosges.
# - **Saint-Germain-des-Prés**: Famous for writers, classic cafés, and elegant stores.
# ...
